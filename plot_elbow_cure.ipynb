# %%
def obtain_errors(season,num_representatives):
    if season !=4:
        errors = spark.read.csv('./CURE_Errors/season='+str(season)+'_num_reps='+str(num_representatives),header=True,inferSchema=True)
    else:
        errors = spark.read.csv('./CURE_Errors/season=EVERYTHING_num_reps='+str(num_representatives),header=True,inferSchema=True)
    fin = errors.orderBy('k').select('error').toPandas().to_numpy()
    print(fin)
    return fin

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
#figure(figsize=(200,200), dpi=60)
# elbow plot
# we have num_reps 4,5,6,7
season = 0
#fig, axs = plt.subplots(4)
#fig.suptitle('CURE: Season=0 (Winter)')
for i in range(4,8):
    plt.plot([j for j in range(3,10)],obtain_errors(season,i))
    plt.xlabel("Number of Clusters")
    plt.ylabel("Sum of Squared Error")
    plt.title("CURE: Season=0 (Winter) Num Reps: " + str(i))
    plt.show()


#plt.plot()
# Out:
# [[5.17999445e+08]
#  [4.09684679e+08]
#  [3.76334598e+08]
#  [3.52142387e+08]
#  [3.02488600e+08]
#  [3.37119914e+08]
#  [2.75841341e+08]]
# [[4.04863206e+08]
#  [4.54540995e+08]
#  [3.37132880e+08]
#  [3.20964611e+08]
#  [3.37121600e+08]
#  [3.12530822e+08]
#  [2.41577075e+08]]
# [[4.14198803e+08]
#  [4.06752935e+08]
#  [3.50270987e+08]
#  [3.22184324e+08]
#  [3.32808195e+08]
#  [2.89190788e+08]
#  [2.94579169e+08]]
# [[4.46468717e+08]
#  [4.19224298e+08]
#  [3.46198856e+08]
#  [3.60336387e+08]
#  [3.29057887e+08]
#  [2.96237945e+08]
#  [3.00796368e+08]]

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
#figure(figsize=(200,200), dpi=60)
# elbow plot
# we have num_reps 4,5,6,7
season = 1
#fig, axs = plt.subplots(4)
#fig.suptitle('CURE: Season=0 (Winter)')
for i in range(4,8):
    plt.plot([j for j in range(3,10)],obtain_errors(season,i))
    plt.xlabel("Number of Clusters")
    plt.ylabel("Sum of Squared Error")
    plt.title("CURE: Season=1 (Spring) Num Reps: " + str(i))
    plt.show()
# Out:
# [[3.22495983e+08]
#  [3.57926440e+08]
#  [3.01340663e+08]
#  [2.77803492e+08]
#  [2.60274897e+08]
#  [2.68480833e+08]
#  [2.53856082e+08]]
# [[3.73254610e+08]
#  [3.11086129e+08]
#  [3.75871152e+08]
#  [2.61119698e+08]
#  [2.37098753e+08]
#  [3.03638676e+08]
#  [2.49430774e+08]]
# [[3.78841815e+08]
#  [2.79776996e+08]
#  [2.88594833e+08]
#  [2.51472742e+08]
#  [2.74402511e+08]
#  [2.34398109e+08]
#  [2.39703474e+08]]
# [[3.23924974e+08]
#  [2.88474879e+08]
#  [2.61022225e+08]
#  [2.44504497e+08]
#  [2.60870562e+08]
#  [2.29368730e+08]
#  [2.51008548e+08]]

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
#figure(figsize=(200,200), dpi=60)
# elbow plot
# we have num_reps 4,5,6,7
season = 2
#fig, axs = plt.subplots(4)
#fig.suptitle('CURE: Season=0 (Winter)')
for i in range(4,8):
    plt.plot([j for j in range(3,10)],obtain_errors(season,i))
    plt.xlabel("Number of Clusters")
    plt.ylabel("Sum of Squared Error")
    plt.title("CURE: Season=2 (Summer) Num Reps: " + str(i))
    plt.show()
# Out:
# [[8.20315360e+08]
#  [4.96881060e+08]
#  [4.36449293e+08]
#  [4.82583496e+08]
#  [3.68244772e+08]
#  [4.33110447e+08]
#  [3.60673967e+08]]
# [[4.80132818e+08]
#  [4.18765806e+08]
#  [4.46016837e+08]
#  [3.32344493e+08]
#  [3.88692420e+08]
#  [3.39340239e+08]
#  [2.90978780e+08]]
# [[4.15084274e+08]
#  [4.75807476e+08]
#  [3.81231126e+08]
#  [4.66129604e+08]
#  [3.91446769e+08]
#  [3.69401551e+08]
#  [3.68791136e+08]]
# [[5.30681530e+08]
#  [4.53988507e+08]
#  [3.98442560e+08]
#  [4.11154030e+08]
#  [3.63094845e+08]
#  [3.21558182e+08]
#  [2.97883933e+08]]

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
#figure(figsize=(200,200), dpi=60)
# elbow plot
# we have num_reps 4,5,6,7
season = 3
#fig, axs = plt.subplots(4)
#fig.suptitle('CURE: Season=0 (Winter)')
for i in range(4,8):
    plt.plot([j for j in range(3,10)],obtain_errors(season,i))
    plt.xlabel("Number of Clusters")
    plt.ylabel("Sum of Squared Error")
    plt.title("CURE: Season=3 (Fall) Num Reps: " + str(i))
    plt.show()
# Out:
# [[3.35280593e+08]
#  [3.03905791e+08]
#  [2.59444040e+08]
#  [2.86826167e+08]
#  [2.90822857e+08]
#  [3.09554129e+08]
#  [2.60259622e+08]]
# [[2.91212767e+08]
#  [3.18399498e+08]
#  [2.95692945e+08]
#  [2.78082245e+08]
#  [2.81035202e+08]
#  [2.55690795e+08]
#  [2.48091442e+08]]
# [[3.19576912e+08]
#  [3.08906893e+08]
#  [3.21830892e+08]
#  [2.85417262e+08]
#  [3.05846854e+08]
#  [3.08133255e+08]
#  [2.48584768e+08]]
# [[3.16310522e+08]
#  [3.19104838e+08]
#  [2.81431573e+08]
#  [2.93341424e+08]
#  [2.62144285e+08]
#  [2.46913802e+08]
#  [2.51803578e+08]]

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
#figure(figsize=(200,200), dpi=60)
# elbow plot
# we have num_reps 4,5,6,7
season = 4
#fig, axs = plt.subplots(4)
#fig.suptitle('CURE: Season=0 (Winter)')
for i in range(4,8):
    plt.plot([j for j in range(3,10)],obtain_errors(season,i))
    plt.xlabel("Number of Clusters")
    plt.ylabel("Sum of Squared Error")
    plt.title("CURE On All Data, Num Reps: " + str(i))
    plt.show()
# Out:
# [[2.23797839e+09]
#  [1.61573998e+09]
#  [1.85525136e+09]
#  [1.40896558e+09]
#  [1.36437123e+09]
#  [1.25334322e+09]
#  [1.31914993e+09]]
# [[1.44383596e+09]
#  [1.49548889e+09]
#  [1.68516121e+09]
#  [1.56464186e+09]
#  [1.25358606e+09]
#  [1.29840018e+09]
#  [1.35605512e+09]]
# [[2.16917376e+09]
#  [1.31059201e+09]
#  [1.31676308e+09]
#  [1.48932963e+09]
#  [1.44158379e+09]
#  [1.22935332e+09]
#  [1.38595306e+09]]
# [[1.83652172e+09]
#  [1.36943791e+09]
#  [1.83467698e+09]
#  [1.54770759e+09]
#  [1.16686900e+09]
#  [1.27777548e+09]
#  [1.25840534e+09]]
